# %% [markdown]
# # How to upload/insert - Image/Text
# # How to write a headline

# %%
# insert Image
from IPython.display import Image
Image("Desktop\AI.jpg")

# %%
#insert image in markdown

# %% [markdown]
# ![title](Desktop\AI.jpg)

# %% [markdown]
# ![title](Desktop\AI.jpg)
